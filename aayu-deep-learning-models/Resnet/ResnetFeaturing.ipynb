# %%
import cv2
import os

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
            print(filename)
    return images

# %%
data =  load_images_from_folder("Diseased/Mango")
# Out:
# 0012_0001_Picsart.png
# 0012_0002_Picsart.png
# 0012_0003_Picsart.png
# 0012_0004_Picsart.png
# 0012_0005_Picsart.png
# 0012_0006_Picsart.png
# 0012_0007_Picsart.png
# 0012_0008_Picsart.png
# 0012_0009_Picsart.png
# 0012_0010_Picsart.png
# 0012_0011_Picsart.png
# 0012_0012_Picsart.png
# 0012_0013_Picsart.png
# 0012_0014_Picsart.png
# 0012_0015_Picsart.png
# 0012_0016_Picsart.png
# 0012_0017_Picsart.png
# 0012_0018_Picsart.png
# 0012_0019_Picsart.png
# 0012_0020_Picsart.png
# 0012_0021_Picsart.png
# 0012_0022_Picsart.png
# 0012_0023_Picsart.png
# 0012_0024_Picsart.png
# 0012_0025_Picsart.png
# 0012_0026_Picsart.png
# 0012_0027_Picsart.png
# 0012_0028_Picsart.png
# 0012_0029_Picsart.png
# 0012_0030_Picsart.png
# 0012_0031_Picsart.png
# 0012_0032_Picsart.png
# 0012_0033_Picsart.png
# 0012_0034_Picsart.png
# 0012_0035_Picsart.png
# 0012_0036_Picsart.png
# 0012_0037_Picsart.png
# 0012_0038_Picsart.png
# 0012_0039_Picsart.png
# 0012_0040_Picsart.png
# 0012_0041_Picsart.png
# 0012_0042_Picsart.png
# 0012_0043_Picsart.png
# 0012_0044_Picsart.png
# 0012_0045_Picsart.png
# 0012_0046_Picsart.png
# 0012_0047_Picsart.png
# 0012_0048_Picsart.png
# 0012_0049_Picsart.png
# 0012_0050_Picsart.png
# 0012_0051_Picsart.png
# 0012_0052_Picsart.png
# 0012_0053_Picsart.png
# 0012_0054_Picsart.png
# 0012_0055_Picsart.png
# 0012_0056_Picsart.png
# 0012_0057_Picsart.png
# 0012_0058_Picsart.png
# 0012_0059_Picsart.png
# 0012_0060_Picsart.png
# 0012_0061_Picsart.png
# 0012_0062_Picsart.png
# 0012_0063_Picsart.png
# 0012_0064_Picsart.png
# 0012_0065_Picsart.png
# 0012_0066_Picsart.png
# 0012_0067_Picsart.png
# 0012_0068_Picsart.png
# 0012_0069_Picsart.png
# 0012_0070_Picsart.png
# 0012_0071_Picsart.png
# 0012_0072_Picsart.png
# 0012_0073_Picsart.png
# 0012_0074_Picsart.png
# 0012_0075_Picsart.png
# 0012_0076_Picsart.png
# 0012_0077_Picsart.png
# 0012_0078_Picsart.png
# 0012_0079_Picsart.png
# 0012_0080_Picsart.png
# 0012_0081_Picsart.png
# 0012_0082_Picsart.png
# 0012_0083_Picsart.png
# 0012_0084_Picsart.png
# 0012_0085_Picsart.png
# 0012_0086_Picsart.png
# 0012_0087_Picsart.png
# 0012_0088_Picsart.png
# 0012_0089_Picsart.png
# 0012_0090_Picsart.png
# 0012_0091_Picsart.png
# 0012_0092_Picsart.png
# 0012_0093_Picsart.png
# 0012_0094_Picsart.png
# 0012_0095_Picsart.png
# 0012_0096_Picsart.png
# 0012_0097_Picsart.png
# 0012_0098_Picsart.png
# 0012_0099_Picsart.png
# 0012_0100_Picsart.png
# 0012_0101_Picsart.png
# 0012_0102_Picsart.png
# 0012_0103_Picsart.png
# 0012_0104_Picsart.png
# 0012_0105_Picsart.png
# 0012_0106_Picsart.png
# 0012_0107_Picsart.png
# 0012_0108_Picsart.png
# 0012_0109_Picsart.png
# 0012_0110_Picsart.png
# 0012_0111_Picsart.png
# 0012_0112_Picsart.png
# 0012_0113_Picsart.png
# 0012_0114_Picsart.png
# 0012_0115_Picsart.png
# 0012_0116_Picsart.png
# 0012_0117_Picsart.png
# 0012_0118_Picsart.png
# 0012_0119_Picsart.png
# 0012_0120_Picsart.png
# 0012_0121_Picsart.png
# 0012_0122_Picsart.png
# 0012_0123_Picsart.png
# 0012_0124_Picsart.png
# 0012_0125_Picsart.png
# 0012_0126_Picsart.png
# 0012_0127_Picsart.png
# 0012_0128_Picsart.png
# 0012_0129_Picsart.png
# 0012_0130_Picsart.png
# 0012_0131_Picsart.png
# 0012_0132_Picsart.png
# 0012_0133_Picsart.png
# 0012_0134_Picsart.png
# 0012_0135_Picsart.png
# 0012_0136_Picsart.png
# 0012_0137_Picsart.png
# 0012_0138_Picsart.png
# 0012_0139_Picsart.png
# 0012_0140_Picsart.png
# 0012_0141_Picsart.png
# 0012_0142_Picsart.png
# 0012_0143_Picsart.png
# 0012_0144_Picsart.png
# 0012_0145_Picsart.png
# 0012_0146_Picsart.png
# 0012_0147_Picsart.png
# 0012_0148_Picsart.png
# 0012_0149_Picsart.png
# 0012_0150_Picsart.png
# 0012_0151_Picsart.png
# 0012_0152_Picsart.png
# 0012_0153_Picsart.png
# 0012_0154_Picsart.png
# 0012_0155_Picsart.png
# 0012_0156_Picsart.png
# 0012_0157_Picsart.png
# 0012_0158_Picsart.png
# 0012_0159_Picsart.png
# 0012_0160_Picsart.png
# 0012_0161_Picsart.png
# 0012_0162_Picsart.png
# 0012_0163_Picsart.png
# 0012_0164_Picsart.png
# 0012_0165_Picsart.png
# 0012_0166_Picsart.png
# 0012_0167_Picsart.png
# 0012_0168_Picsart.png
# 0012_0169_Picsart.png
# 0012_0170_Picsart.png
# 0012_0171_Picsart.png
# 0012_0172_Picsart.png
# 0012_0173_Picsart.png
# 0012_0174_Picsart.png
# 0012_0175_Picsart.png
# 0012_0176_Picsart.png
# 0012_0177_Picsart.png
# 0012_0178_Picsart.png
# 0012_0179_Picsart.png
# 0012_0180_Picsart.png
# 0012_0181_Picsart.png
# 0012_0182_Picsart.png
# 0012_0183_Picsart.png
# 0012_0184_Picsart.png
# 0012_0185_Picsart.png
# 0012_0186_Picsart.png
# 0012_0187_Picsart.png
# 0012_0188_Picsart.png
# 0012_0189_Picsart.png
# 0012_0190_Picsart.png
# 0012_0191_Picsart.png
# 0012_0192_Picsart.png
# 0012_0193_Picsart.png
# 0012_0194_Picsart.png
# 0012_0195_Picsart.png
# 0012_0196_Picsart.png
# 0012_0197_Picsart.png
# 0012_0198_Picsart.png
# 0012_0199_Picsart.png
# 0012_0200_Picsart.png
# 0012_0201_Picsart.png
# 0012_0202_Picsart.png
# 0012_0204_Picsart.png
# 0012_0205_Picsart.png
# 0012_0206_Picsart.png
# 0012_0207_Picsart.png
# 0012_0208_Picsart.png
# 0012_0209_Picsart.png
# 0012_0210_Picsart.png
# 0012_0211_Picsart.png
# 0012_0212_Picsart.png
# 0012_0213_Picsart.png
# 0012_0214_Picsart.png
# 0012_0215_Picsart.png
# 0012_0216_Picsart.png
# 0012_0217_Picsart.png
# 0012_0218_Picsart.png
# 0012_0219_Picsart.png
# 0012_0220_Picsart.png
# 0012_0221_Picsart.png
# 0012_0222_Picsart.png
# 0012_0223_Picsart.png
# 0012_0224_Picsart.png
# 0012_0225_Picsart.png
# 0012_0226_Picsart.png
# 0012_0227_Picsart.png
# 0012_0228_Picsart.png
# 0012_0229_Picsart.png
# 0012_0230_Picsart.png
# 0012_0231_Picsart.png
# 0012_0232_Picsart.png
# 0012_0233_Picsart.png
# 0012_0234_Picsart.png
# 0012_0235_Picsart.png
# 0012_0236_Picsart.png
# 0012_0237_Picsart.png
# 0012_0238_Picsart.png
# 0012_0239_Picsart.png
# 0012_0240_Picsart.png
# 0012_0241_Picsart.png
# 0012_0242_Picsart.png
# 0012_0243_Picsart.png
# 0012_0244_Picsart.png
# 0012_0245_Picsart.png
# 0012_0246_Picsart.png
# 0012_0247_Picsart.png
# 0012_0248_Picsart.png
# 0012_0249_Picsart.png
# 0012_0250_Picsart.png
# 0012_0251_Picsart.png
# 0012_0252_Picsart.png
# 0012_0253_Picsart.png
# 0012_0254_Picsart.png
# 0012_0255_Picsart.png
# 0012_0256_Picsart.png
# 0012_0257_Picsart.png
# 0012_0258_Picsart.png
# 0012_0259_Picsart.png
# 0012_0260_Picsart.png
# 0012_0261_Picsart.png
# 0012_0262_Picsart.png
# 0012_0263_Picsart.png
# 0012_0264_Picsart.png
# 0012_0265_Picsart.png

# %%
print(len(data))
# Out:
# 264

# %%
inputImg = data[0]
width = int(inputImg.shape[1])
height = int(inputImg.shape[0])

print('Height : ',height)
print('Width : ',width)
# Out:
# Height :  1273
# Width :  5200

# %%
borderType = cv2.BORDER_CONSTANT
colorBorder = [255, 255, 255]

if (height > width) :
    h = int((height-width)/2)
    output = cv2.copyMakeBorder(inputImg, 0, 0, h, h, borderType, None, colorBorder) 
    print("Width Increase")
else :
    w = int((width-height)/2)
    output = cv2.copyMakeBorder(inputImg, w, w, 0, 0, borderType, None, colorBorder)
    print("Height Increase")
# Out:
# Height Increase

# %%
scale_percent = 60
width = int(output.shape[1] * scale_percent / 1000)
height = int(output.shape[0] * scale_percent / 1000)
dsize = (width, height)
outputImg = cv2.resize(output, dsize)

# %%
# Display Image using OpenCV2
cv2.imshow("Preview Image", outputImg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
fileName = os.listdir()
print(fileName)
# Out:
# ['.ipynb_checkpoints', '1.png', '2.png', 'Diseased', 'lemonDi', 'resizeimg.png', 'ResizeResnet.ipynb', 'ResnetFeaturing.ipynb']
